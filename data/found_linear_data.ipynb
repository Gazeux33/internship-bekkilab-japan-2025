# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Admission_Predict.csv')

# %%
# Serial No.,GRE Score,TOEFL Score,University Rating,SOP,LOR ,CGPA,Research,Chance of Admit 
plt.scatter(data['GRE Score'], data['TOEFL Score'], color='blue', label='GRE Score');

# %%
plt.scatter(data['TOEFL Score'], data['University Rating'], color='blue', label='GRE Score');
